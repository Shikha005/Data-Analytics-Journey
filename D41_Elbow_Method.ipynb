# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

x, _ = make_blobs(n_samples=300, centers=4,
                  random_state=42, cluster_std=1.2)

inertia = []
k_values = range(1, 11)

for k in k_values:
    model = KMeans(n_clusters=k, random_state=42, n_init=10)
    model.fit(x)
    inertia.append(model.inertia_)

print("elbow method results")
print("-" * 30)
for i, k in enumerate(k_values):
    print("k =", k, "-> inertia:", round(inertia[i], 2))

plt.figure(figsize=(8, 5))
plt.plot(k_values, inertia, marker="o", color="steelblue")
plt.title("elbow method - finding best k")
plt.xlabel("number of clusters")
plt.ylabel("inertia")
plt.tight_layout()
plt.show()
# Out:
# elbow method results
# ------------------------------
# k = 1 -> inertia: 20172.95
# k = 2 -> inertia: 9666.83
# k = 3 -> inertia: 2346.88
# k = 4 -> inertia: 805.48
# k = 5 -> inertia: 729.97
# k = 6 -> inertia: 656.62
# k = 7 -> inertia: 585.09
# k = 8 -> inertia: 514.35
# k = 9 -> inertia: 461.21
# k = 10 -> inertia: 411.74
