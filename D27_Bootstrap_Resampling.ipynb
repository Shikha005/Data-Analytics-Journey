# %%
import numpy as np

data = np.array([23, 45, 12, 67, 34, 89, 21, 56, 78, 90])

n_iterations = 1000
n_size = len(data)
bootstrap_means = []

np.random.seed(42)

for _ in range(n_iterations):
    sample = np.random.choice(data, size=n_size, replace=True)
    bootstrap_means.append(np.mean(sample))

bootstrap_means = np.array(bootstrap_means)

lower_bound = np.percentile(bootstrap_means, 2.5)
upper_bound = np.percentile(bootstrap_means, 97.5)

print("Original Data Mean:", np.mean(data))
print("Bootstrap Mean:", np.mean(bootstrap_means))
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Original Data Mean: 51.5
# Bootstrap Mean: 51.5231
# 95% Confidence Interval: (35.09, 67.61)
