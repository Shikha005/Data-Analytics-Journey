# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv("student_performance.csv")

# %%
x = df[["hours_studied", "attendance", "previous_score", "sleep_hours"]]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
model = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = model.fit_predict(X_scaled)

# %%
df["cluster"] = clusters

# %%
sil_score = silhouette_score(X_scaled, clusters)

# %%
print("=== K-Means Clustering ===")
print(f"Silhouette score: {sil_score:.3f}")
print("\nCluster sizes:")
print(df["cluster"].value_counts())
# Out:
# === K-Means Clustering ===
# Silhouette score: 0.206
#
# Cluster sizes:
# cluster
# 2    72
# 0    72
# 1    56
# Name: count, dtype: int64

# %%
print("\nAverage feature values per cluster:")
print(df.groupby("cluster")[["hours_studied", "attendance", "previous_score", "sleep_hours", "final_score"]].mean())
# Out:
# Average feature values per cluster:
#          hours_studied  attendance  previous_score  sleep_hours  final_score
# cluster
# 0             4.718056   63.894444       83.016667     5.979167    85.355556
# 1             4.714286   87.400000       71.192857     7.819643    87.683929
# 2             5.066667   77.069444       46.184722     5.693056    78.243056
