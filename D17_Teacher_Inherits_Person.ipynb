# %%
class Person:

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print("hi i am", self.name)
        print("i am", self.age, "years old")

class Teacher(Person):

    def __init__(self, name, age, subject):
        super().__init__(name, age)
        self.subject = subject

    def teach(self):
        print(self.name, "is teaching", self.subject)


t1 = Teacher("mrs sharma", 35, "maths")
t2 = Teacher("mr verma", 42, "science")

t1.introduce()
t1.teach()
print("-" * 25)
t2.introduce()
t2.teach()
# Out:
# hi i am mrs sharma
# i am 35 years old
# mrs sharma is teaching maths
# -------------------------
# hi i am mr verma
# i am 42 years old
# mr verma is teaching science
