# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

data = np.array([
    [2.5, 2.4, 1.2, 3.1],
    [0.5, 0.7, 0.9, 1.1],
    [2.2, 2.9, 1.5, 3.3],
    [1.9, 2.2, 1.1, 2.8],
    [3.1, 3.0, 1.8, 3.5],
    [2.3, 2.7, 1.3, 3.0]
])

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)

print("Original Shape:", data.shape)
print("Reduced Shape:", principal_components.shape)
print("\nExplained Variance Ratio:", pca.explained_variance_ratio_)
print("\nPrincipal Components:\n", principal_components)
# Out:
# Original Shape: (6, 4)
# Reduced Shape: (6, 2)
#
# Explained Variance Ratio: [0.92101697 0.06061083]
#
# Principal Components:
#  [[ 0.35077164 -0.56368317]
#  [-3.82364387  0.47921764]
#  [ 1.10763073  0.14612317]
#  [-0.51990545 -0.52798057]
#  [ 2.36505117  0.73237466]
#  [ 0.52009578 -0.26605172]]
