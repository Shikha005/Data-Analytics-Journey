# %%
import numpy as np
from scipy import stats

data = np.array([102, 98, 105, 110, 99, 101, 108, 95, 100, 103])

mean = np.mean(data)
std_err = stats.sem(data)
confidence_level = 0.95

confidence_interval = stats.t.interval(
    confidence_level,
    len(data) - 1,
    loc=mean,
    scale=std_err
)

print("Data:", data)
print("Sample Mean:", mean)
print(f"{int(confidence_level*100)}% Confidence Interval:", confidence_interval)
# Out:
# Data: [102  98 105 110  99 101 108  95 100 103]
# Sample Mean: 102.1
# 95% Confidence Interval: (np.float64(98.82269018678174), np.float64(105.37730981321825))
