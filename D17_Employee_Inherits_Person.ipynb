# %%
class Person:

    def __init__(self, name, age, city):
        self.name = name
        self.age = age
        self.city = city

    def introduce(self):
        print("name:", self.name)
        print("age:", self.age)
        print("city:", self.city)

class Employee(Person):

    def __init__(self, name, age, city, company, salary):
        super().__init__(name, age, city)
        self.company = company
        self.salary = salary

    def work(self):
        print(self.name, "is working at", self.company)

    def show_salary(self):
        print("salary: Rs.", self.salary, "per month")

    def appraisal(self, percent):
        hike = self.salary * (percent / 100)
        self.salary = self.salary + hike
        print(percent, "% hike given!")
        print("new salary: Rs.", self.salary)

e1 = Employee("priya", 25, "indore", "tcs", 45000)
e2 = Employee("rahul", 28, "bhopal", "infosys", 60000)

print("=== employee 1 ===")
e1.introduce()
e1.work()
e1.show_salary()
e1.appraisal(10)

print("-" * 25)
print("=== employee 2 ===")
e2.introduce()
e2.work()
e2.show_salary()
e2.appraisal(15)
# Out:
# === employee 1 ===
# name: priya
# age: 25
# city: indore
# priya is working at tcs
# salary: Rs. 45000 per month
# 10 % hike given!
# new salary: Rs. 49500.0
# -------------------------
# === employee 2 ===
# name: rahul
# age: 28
# city: bhopal
# rahul is working at infosys
# salary: Rs. 60000 per month
# 15 % hike given!
# new salary: Rs. 69000.0
