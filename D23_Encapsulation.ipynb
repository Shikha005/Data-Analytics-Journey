# %%
class Person:
    def __init__(self, name, age, email):
        self.__name = name
        self.__age = age
        self.__email = email

    def display_info(self):
        print(f"Name: {self.__name}, Age: {self.__age}, Email: {self.__email}")

    def update_email(self, new_email):
        if "@" in new_email:
            self.__email = new_email
            print("Email updated successfully.")
        else:
            print("Invalid email format.")

    def update_age(self, new_age):
        if new_age > 0:
            self.__age = new_age
        else:
            print("Age must be positive.")


person = Person("Aman", 25, "aman@example.com")
person.display_info()

person.update_email("aman.new@example.com")
person.update_age(26)
person.display_info()
# Out:
# Name: Aman, Age: 25, Email: aman@example.com
# Email updated successfully.
# Name: Aman, Age: 26, Email: aman.new@example.com
