# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

iris = load_iris()
x = iris.data
y = iris.target

print("original shape:", x.shape)  # 4 features

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)

print("after pca shape:", x_pca.shape)  # 2 features
print("-" * 35)
print("explained variance ratio:")
for i, var in enumerate(pca.explained_variance_ratio_):
    print("component", i+1, "->", round(var * 100, 2), "%")
print("total variance kept:",
      round(sum(pca.explained_variance_ratio_) * 100, 2), "%")

colors = ["red", "green", "blue"]
plt.figure(figsize=(8, 5))
for i in range(3):
    mask = y == i
    plt.scatter(x_pca[mask, 0], x_pca[mask, 1],
                c=colors[i], label=iris.target_names[i], alpha=0.7)

plt.title("iris dataset - pca 2 components")
plt.xlabel("component 1")
plt.ylabel("component 2")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# original shape: (150, 4)
# after pca shape: (150, 2)
# -----------------------------------
# explained variance ratio:
# component 1 -> 72.96 %
# component 2 -> 22.85 %
# total variance kept: 95.81 %
