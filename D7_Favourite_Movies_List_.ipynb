# %%
import random

movies = ["pushpa", "pathaan", "kgf", "brahmastra", "uri"]

print("my movie picker")
print("-" * 25)

print("my favourite movies:")
for movie in movies:
    print("->", movie)

print("-" * 25)

pick = random.choice(movies)
print("watch tonight:", pick)
# Out:
# my movie picker
# -------------------------
# my favourite movies:
# -> pushpa
# -> pathaan
# -> kgf
# -> brahmastra
# -> uri
# -------------------------
# watch tonight: brahmastra
