# %%
import random

breakfast = ["poha", "paratha", "maggi", "bread butter", "upma"]
lunch = ["dal rice", "rajma", "chole", "biryani", "roti sabzi"]
dinner = ["khichdi", "dosa", "roti dal", "fried rice", "soup"]

print("meal planner for today")
print("-" * 25)

b = random.choice(breakfast)
l = random.choice(lunch)
d = random.choice(dinner)

print("breakfast ->", b)
print("lunch     ->", l)
print("dinner    ->", d)

print("-" * 25)
print("no more thinking about food!")
# Out:
# meal planner for today
# -------------------------
# breakfast -> upma
# lunch     -> biryani
# dinner    -> soup
# -------------------------
# no more thinking about food!
