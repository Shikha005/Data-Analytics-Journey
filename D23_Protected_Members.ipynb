# %%
class Vehicle:
    def __init__(self, brand, speed):
        self._brand = brand   # protected variable
        self._speed = speed   # protected variable

    def show_details(self):
        print(f"Brand: {self._brand}, Speed: {self._speed} km/h")


class Car(Vehicle):
    def increase_speed(self, amount):
        self._speed += amount
        print(f"Speed increased to {self._speed} km/h")


car = Car("Toyota", 120)
car.show_details()
car.increase_speed(30)
car.show_details()
# Out:
# Brand: Toyota, Speed: 120 km/h
# Speed increased to 150 km/h
# Brand: Toyota, Speed: 150 km/h
