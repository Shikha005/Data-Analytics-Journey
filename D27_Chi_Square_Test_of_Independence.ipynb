# %%
import numpy as np
from scipy.stats import chi2_contingency

observed = np.array([
    [30, 20],
    [15, 35]
])

chi2_stat, p_value, dof, expected = chi2_contingency(observed)

print("Observed Table:\n", observed)
print("\nExpected Table:\n", expected)
print("\nChi-Square Statistic:", chi2_stat)
print("Degrees of Freedom:", dof)
print("P-Value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Result: Variables are dependent (significant association).")
else:
    print("Result: Variables are independent (no significant association).")
# Out:
# Observed Table:
#  [[30 20]
#  [15 35]]
#
# Expected Table:
#  [[22.5 27.5]
#  [22.5 27.5]]
#
# Chi-Square Statistic: 7.919191919191919
# Degrees of Freedom: 1
# P-Value: 0.004891311452359333
# Result: Variables are dependent (significant association).
