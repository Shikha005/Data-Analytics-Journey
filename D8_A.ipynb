# %%
import pandas as pd
data = {
    "name": ["priya", "rahul", "sneha", "amit", "pooja"],
    "age": [20, 22, 19, 21, 20],
    "city": ["indore", "bhopal", "delhi", "mumbai", "indore"],
    "marks": [85, 72, 90, 65, 78]
}

df = pd.DataFrame(data)

print("my first dataframe!")
print("-" * 30)
print(df)
print("-" * 30)

print("shape:", df.shape)
print("columns:", list(df.columns))

print("-" * 30)
# first 3 rows
print("first 3 rows:")
print(df.head(3))
# Out:
# my first dataframe!
# ------------------------------
#     name  age    city  marks
# 0  priya   20  indore     85
# 1  rahul   22  bhopal     72
# 2  sneha   19   delhi     90
# 3   amit   21  mumbai     65
# 4  pooja   20  indore     78
# ------------------------------
# shape: (5, 4)
# columns: ['name', 'age', 'city', 'marks']
# ------------------------------
# first 3 rows:
#     name  age    city  marks
# 0  priya   20  indore     85
# 1  rahul   22  bhopal     72
# 2  sneha   19   delhi     90
